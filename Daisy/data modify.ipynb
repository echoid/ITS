# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("adult_train.csv")
data.head()
# Out:
#    age workclass  fnlwgt  education  education-num      marital-status  \
# 0   38   Private  215646    HS-grad              9            Divorced
# 1   53   Private  234721       11th              7  Married-civ-spouse
# 2   28   Private  338409  Bachelors             13  Married-civ-spouse
# 3   37   Private  284582    Masters             14  Married-civ-spouse
# 4   31   Private   45781    Masters             14       Never-married
#
#           occupation   relationship   race     sex  capital-gain  \
# 0  Handlers-cleaners  Not-in-family  White    Male             0
# 1  Handlers-cleaners        Husband  Black    Male             0
# 2     Prof-specialty           Wife  Black  Female             0
# 3    Exec-managerial           Wife  White  Female             0
# 4     Prof-specialty  Not-in-family  White  Female         14084
#
#    capital-loss  hours-per-week native-country income
# 0             0              40  United-States  <=50K
# ...

# %%
print(data.dtypes)
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
data.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076583       0.037131      0.081087      0.065339
# fnlwgt         -0.076583  1.000000      -0.042256     -0.006900     -0.005674
# education-num   0.037131 -0.042256       1.000000      0.123024      0.077503
# capital-gain    0.081087 -0.006900       0.123024      1.000000     -0.032588
# capital-loss    0.065339 -0.005674       0.077503     -0.032588      1.000000
# hours-per-week  0.104062 -0.019588       0.151677      0.086685      0.060316
#
#                 hours-per-week
# age                   0.104062
# fnlwgt               -0.019588
# education-num         0.151677
# capital-gain          0.086685
# capital-loss          0.060316
# hours-per-week        1.000000

# %%
new_data = data
new_data["capital-gain"] = data["education-num"] * 500
new_data["capital-gain"] = data["education-num"] * 500

# %%
new_data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
new_data
# Out:
#        age     workclass  fnlwgt  education  education-num  \
# 0       38       Private  215646    HS-grad              9
# 1       53       Private  234721       11th              7
# 2       28       Private  338409  Bachelors             13
# 3       37       Private  284582    Masters             14
# 4       31       Private   45781    Masters             14
# ...    ...           ...     ...        ...            ...
# 30143   25       Private  350977    HS-grad              9
# 30144   39       Private  215419  Bachelors             13
# 30145   38       Private  374983  Bachelors             13
# 30146   44       Private   83891  Bachelors             13
# 30147   35  Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation   relationship  \
# 0                Divorced  Handlers-cleaners  Not-in-family
# 1      Married-civ-spouse  Handlers-cleaners        Husband
# 2      Married-civ-spouse     Prof-specialty           Wife
# ...

# %%
new_data.to_csv("modified_adult_train.csv",index=False)

# %%
new_data.shape
# Out:
# (30148, 15)

# %%
sampled = new_data.sample(n=int(new_data.shape[0]*0.05), random_state=1)

# %%
sampled = new_data.sample(n=int(new_data.shape[0]*0.05), random_state=1)
sampled.to_csv("modified_adult_train_sample.csv",index=False)

# %%
sampled = data.sample(n=int(data.shape[0]*0.05), random_state=1)
sampled.to_csv("adult_train_sample.csv",index=False)
